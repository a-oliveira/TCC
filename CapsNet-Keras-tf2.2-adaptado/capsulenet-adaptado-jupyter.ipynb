# %%
"""
Keras implementation of CapsNet in Hinton's paper Dynamic Routing Between Capsules.
The current version maybe only works for TensorFlow backend. Actually it will be straightforward to re-write to TF code.
Adopting to other backends should be easy, but I have not tested this. 

Usage:
       python capsulenet.py
       python capsulenet.py --epochs 50
       python capsulenet.py --epochs 50 --routings 3
       ... ...
       
Result:
    Validation accuracy > 99.5% after 20 epochs. Converge to 99.66% after 50 epochs.
    About 110 seconds per epoch on a single GTX1070 GPU card
    
Author: Xifeng Guo, E-mail: `guoxifeng1990@163.com`, Github: `https://github.com/XifengGuo/CapsNet-Keras`
"""

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from utils import combine_images
#from PIL import Image
#import PIL
import load_data2 as ld
from capsulelayers import CapsuleLayer, PrimaryCap, Length, Mask

CONJ_TREINO = '/Users/Pandessa/Documents/MEGA/UFRRJ/TCC/Projeto/CONJ_TREINO/*.jpg'
CONJ_TESTE = '/Users/Pandessa/Documents/MEGA/UFRRJ/TCC/Projeto/CONJ_TESTE/*.jpg'

K.set_image_data_format('channels_last')


def CapsNet(input_shape, n_class, routings, batch_size):
    """
    A Capsule Network on MNIST.
    :param input_shape: data shape, 3d, [width, height, channels]
    :param n_class: number of classes
    :param routings: number of routing iterations
    :param batch_size: size of batch
    :return: Two Keras Models, the first one used for training, and the second one for evaluation.
            `eval_model` can also be used for training.
    """
    x = layers.Input(shape=input_shape, batch_size=batch_size)

    # Layer 1: Just a conventional Conv2D layer
    conv1 = layers.Conv2D(filters=256, kernel_size=9, strides=1, padding='valid', activation='relu', name='conv1')(x)

    # Layer 2: Conv2D layer with `squash` activation, then reshape to [None, num_capsule, dim_capsule]
    primarycaps = PrimaryCap(conv1, dim_capsule=8, n_channels=32, kernel_size=9, strides=2, padding='valid')

    # Layer 3: Capsule layer. Routing algorithm works here.
    digitcaps = CapsuleLayer(num_capsule=n_class, dim_capsule=16, routings=routings, name='digitcaps')(primarycaps)

    # Layer 4: This is an auxiliary layer to replace each capsule with its length. Just to match the true label's shape.
    # If using tensorflow, this will not be necessary. :)
    out_caps = Length(name='capsnet')(digitcaps)

    # Decoder network.
    y = layers.Input(shape=(n_class,))
    masked_by_y = Mask()([digitcaps, y])  # The true label is used to mask the output of capsule layer. For training
    masked = Mask()(digitcaps)  # Mask using the capsule with maximal length. For prediction

    # Shared Decoder model in training and prediction
    decoder = models.Sequential(name='decoder')
    decoder.add(layers.Dense(512, activation='relu', input_dim=16 * n_class))
    decoder.add(layers.Dense(1024, activation='relu'))
    decoder.add(layers.Dense(np.prod(input_shape), activation='sigmoid'))
    decoder.add(layers.Reshape(target_shape=input_shape, name='out_recon'))

    # Models for training and evaluation (prediction)
    train_model = models.Model([x, y], [out_caps, decoder(masked_by_y)])
    eval_model = models.Model(x, [out_caps, decoder(masked)])

    # manipulate model
    noise = layers.Input(shape=(n_class, 16))
    noised_digitcaps = layers.Add()([digitcaps, noise])
    masked_noised_y = Mask()([noised_digitcaps, y])
    manipulate_model = models.Model([x, y, noise], decoder(masked_noised_y))
    return train_model, eval_model, manipulate_model


def margin_loss(y_true, y_pred):
    """
    Margin loss for Eq.(4). When y_true[i, :] contains not just one `1`, this loss should work too. Not test it.
    :param y_true: [None, n_classes]
    :param y_pred: [None, num_capsule]
    :return: a scalar loss value.
    """
    # return tf.reduce_mean(tf.square(y_pred))
    L = y_true * tf.square(tf.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * tf.square(tf.maximum(0., y_pred - 0.1))

    return tf.reduce_mean(tf.reduce_sum(L, 1))


def train(model,  # type: models.Model
          data, args):
    """
    Training a CapsuleNet
    :param model: the CapsuleNet model
    :param data: a tuple containing training and testing data, like `((x_train, y_train), (x_test, y_test))`
    :param args: arguments
    :return: The trained model
    """
    # unpacking the data
    (x_train, y_train), (x_test, y_test) = data

    # callbacks
    log = callbacks.CSVLogger(args.save_dir + '/log.csv')
    checkpoint = callbacks.ModelCheckpoint(args.save_dir + '/weights-{epoch:02d}.h5', monitor='val_capsnet_acc',
                                           save_best_only=True, save_weights_only=True, verbose=1)
    lr_decay = callbacks.LearningRateScheduler(schedule=lambda epoch: args.lr * (args.lr_decay ** epoch))

    # compile the model
    model.compile(optimizer=optimizers.Adam(lr=args.lr),
                  loss=[margin_loss, 'mse'],
                  loss_weights=[1., args.lam_recon],
                  metrics={'capsnet': 'accuracy'})

    
    # Training without data augmentation:
    model.fit([x_train, y_train], [y_train, x_train], batch_size=args.batch_size, epochs=args.epochs,
              validation_data=[[x_test, y_test], [y_test, x_test]], callbacks=[log, checkpoint, lr_decay])
    
    """
    # Begin: Training with data augmentation ---------------------------------------------------------------------#
    def train_generator(x, y, batch_size, shift_fraction=0.):
        train_datagen = ImageDataGenerator(width_shift_range=shift_fraction,
                                           height_shift_range=shift_fraction)  # shift up to 2 pixel for MNIST
        generator = train_datagen.flow(x, y, batch_size=batch_size)
        while 1:
            x_batch, y_batch = generator.next()
            yield (x_batch, y_batch), (y_batch, x_batch)

    # Training with data augmentation. If shift_fraction=0., no augmentation.
    model.fit(train_generator(x_train, y_train, args.batch_size, args.shift_fraction),
              steps_per_epoch=int(y_train.shape[0] / args.batch_size),
              epochs=args.epochs,
              validation_data=((x_test, y_test), (y_test, x_test)), batch_size=args.batch_size,
              callbacks=[log, checkpoint, lr_decay])
    # End: Training with data augmentation -----------------------------------------------------------------------#
    """
    model.save_weights(args.save_dir + '/trained_model.h5')
    print('Trained model saved to \'%s/trained_model.h5\'' % args.save_dir)

    from utils import plot_log
    plot_log(args.save_dir + '/log.csv', show=True)

    return model


def test(model, data, args):
    print('-' * 30 + 'Begin: test' + '-' * 30)
    x_test, y_test = data
    y_pred, x_recon = model.predict(x_test, batch_size=100)
    print('Test acc:', np.sum(np.argmax(y_pred, 1) == np.argmax(y_test, 1)) / y_test.shape[0])
    print('Testing multiclass prediction for the first image:', np.argsort(-y_pred[0])[:3])
    '''
    img = combine_images(np.concatenate([x_test[:50], x_recon[:50]]))
    image = img * 255
    Image.fromarray(image.astype(np.uint8)).save(args.save_dir + "/real_and_recon.png")
    print()
    print('Reconstructed images are saved to %s/real_and_recon.png' % args.save_dir)
    print('-' * 30 + 'End: test' + '-' * 30)
    plt.imshow(plt.imread(args.save_dir + "/real_and_recon.png"))
    plt.show()
    '''


def manipulate_latent(model, data, args):
    print('-' * 30 + 'Begin: manipulate' + '-' * 30)
    x_test, y_test = data
    index = np.argmax(y_test, 1) == args.digit
    number = np.random.randint(low=0, high=sum(index) - 1)
    x, y = x_test[index][number], y_test[index][number]
    x, y = np.expand_dims(x, 0), np.expand_dims(y, 0)
    noise = np.zeros([1, 10, 16])
    x_recons = []
    for dim in range(16):
        for r in [-0.25, -0.2, -0.15, -0.1, -0.05, 0, 0.05, 0.1, 0.15, 0.2, 0.25]:
            tmp = np.copy(noise)
            tmp[:, :, dim] = r
            x_recon = model.predict([x, y, tmp])
            x_recons.append(x_recon)

    x_recons = np.concatenate(x_recons)

    img = combine_images(x_recons, height=16)
    image = img * 255
    Image.fromarray(image.astype(np.uint8)).save(args.save_dir + '/manipulate-%d.png' % args.digit)
    print('manipulated result saved to %s/manipulate-%d.png' % (args.save_dir, args.digit))
    print('-' * 30 + 'End: manipulate' + '-' * 30)


def load_mnist():
    # the data, shuffled and split between train and test sets
    from tensorflow.keras.datasets import mnist
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.
    x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.
    y_train = to_categorical(y_train.astype('float32'))
    y_test = to_categorical(y_test.astype('float32'))
    return (x_train, y_train), (x_test, y_test)


def load_cifar():
    # the data, shuffled and split between train and test sets
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    x_train = x_train.reshape(-1, 32, 32, 3).astype('float32') / 255.
    x_test = x_test.reshape(-1, 32, 32, 3).astype('float32') / 255.
    y_train = to_categorical(y_train.astype('float32'))
    y_test = to_categorical(y_test.astype('float32'))
    return (x_train, y_train), (x_test, y_test)



x_train, y_train = ld.load_data(CONJ_TREINO)
x_test, y_test = ld.load_data(CONJ_TESTE)
print("O SHAPE DO X É {}\nE O SHAPE DO Y É {}!".format(x_train.shape[1:], y_train.shape))

# define model
model, eval_model, manipulate_model = CapsNet(input_shape=x_train.shape[1:],#np.shape(x_train),
                                                  n_class=5,
                                                  routings=3, #args.routings,
                                                  batch_size=100) #args.batch_size)
model.summary()

train(model=model, data=((x_train, y_train), (x_test, y_test)), args=args)
# Out:
# Erro ao abrir a imagem 100.
# Erro ao abrir a imagem 1017.
# Erro ao abrir a imagem 1053.
# Erro ao abrir a imagem 1059.
# Erro ao abrir a imagem 1084.
# Erro ao abrir a imagem 1091.
# Erro ao abrir a imagem 1106.
# Erro ao abrir a imagem 1107.
# Erro ao abrir a imagem 1109.
# Erro ao abrir a imagem 1131.
# Erro ao abrir a imagem 1140.
# Erro ao abrir a imagem 1168.
# Erro ao abrir a imagem 1183.
# Erro ao abrir a imagem 1187.
# Erro ao abrir a imagem 1192.
# Erro ao abrir a imagem 1202.
# Erro ao abrir a imagem 1203.
# Erro ao abrir a imagem 1224.
# Erro ao abrir a imagem 1226.
# Erro ao abrir a imagem 1237.
# Erro ao abrir a imagem 1240.
# Erro ao abrir a imagem 1254.
# Erro ao abrir a imagem 1255.
# Erro ao abrir a imagem 1260.
# Erro ao abrir a imagem 1276.
# Erro ao abrir a imagem 1280.
# Erro ao abrir a imagem 1300.
# Erro ao abrir a imagem 1306.
# Erro ao abrir a imagem 1308.
# Erro ao abrir a imagem 1310.
# Erro ao abrir a imagem 1315.
# Erro ao abrir a imagem 1324.
# Erro ao abrir a imagem 1333.
# Erro ao abrir a imagem 1337.
# Erro ao abrir a imagem 1350.
# Erro ao abrir a imagem 1365.
# Erro ao abrir a imagem 1369.
# Erro ao abrir a imagem 1370.
# Erro ao abrir a imagem 1386.
# Erro ao abrir a imagem 1387.
# Erro ao abrir a imagem 1398.
# Erro ao abrir a imagem 1400.
# Erro ao abrir a imagem 1404.
# Erro ao abrir a imagem 1409.
# Erro ao abrir a imagem 1412.
# Erro ao abrir a imagem 1421.
# Erro ao abrir a imagem 1425.
# Erro ao abrir a imagem 1426.
# Erro ao abrir a imagem 1437.
# Erro ao abrir a imagem 1442.
# Erro ao abrir a imagem 1459.
# Erro ao abrir a imagem 1468.
# Erro ao abrir a imagem 1479.
# Erro ao abrir a imagem 1482.
# Erro ao abrir a imagem 1492.
# Erro ao abrir a imagem 1496.
# Erro ao abrir a imagem 1503.
# Erro ao abrir a imagem 1520.
# Erro ao abrir a imagem 1543.
# Erro ao abrir a imagem 1548.
# Erro ao abrir a imagem 155.
# Erro ao abrir a imagem 1555.
# Erro ao abrir a imagem 1558.
# Erro ao abrir a imagem 1572.
# Erro ao abrir a imagem 1577.
# Erro ao abrir a imagem 158.
# Erro ao abrir a imagem 1592.
# Erro ao abrir a imagem 160.
# Erro ao abrir a imagem 1637.
# Erro ao abrir a imagem 1638.
# Erro ao abrir a imagem 1655.
# Erro ao abrir a imagem 1657.
# Erro ao abrir a imagem 1671.
# Erro ao abrir a imagem 1679.
# Erro ao abrir a imagem 1683.
# Erro ao abrir a imagem 1691.
# Erro ao abrir a imagem 1699.
# Erro ao abrir a imagem 1709.
# Erro ao abrir a imagem 1720.
# Erro ao abrir a imagem 1722.
# Erro ao abrir a imagem 1725.
# Erro ao abrir a imagem 1739.
# Erro ao abrir a imagem 1740.
# Erro ao abrir a imagem 1750.
# Erro ao abrir a imagem 1754.
# Erro ao abrir a imagem 1756.
# Erro ao abrir a imagem 1764.
# Erro ao abrir a imagem 1769.
# Erro ao abrir a imagem 1771.
# Erro ao abrir a imagem 1775.
# Erro ao abrir a imagem 1777.
# Erro ao abrir a imagem 1778.
# Erro ao abrir a imagem 1785.
# Erro ao abrir a imagem 1807.
# Erro ao abrir a imagem 1841.
# Erro ao abrir a imagem 1853.
# Erro ao abrir a imagem 1858.
# Erro ao abrir a imagem 1865.
# Erro ao abrir a imagem 1876.
# Erro ao abrir a imagem 1880.
# Erro ao abrir a imagem 1903.
# Erro ao abrir a imagem 1927.
# Erro ao abrir a imagem 1945.
# Erro ao abrir a imagem 1958.
# Erro ao abrir a imagem 1968.
# Erro ao abrir a imagem 199.
# Erro ao abrir a imagem 2010.
# Erro ao abrir a imagem 2023.
# Erro ao abrir a imagem 2039.
# Erro ao abrir a imagem 2044.
# Erro ao abrir a imagem 2046.
# Erro ao abrir a imagem 2047.
# Erro ao abrir a imagem 207.
# Erro ao abrir a imagem 2079.
# Erro ao abrir a imagem 2088.
# Erro ao abrir a imagem 2097.
# Erro ao abrir a imagem 2100.
# Erro ao abrir a imagem 2136.
# Erro ao abrir a imagem 2137.
# Erro ao abrir a imagem 2149.
# Erro ao abrir a imagem 2164.
# Erro ao abrir a imagem 2165.
# Erro ao abrir a imagem 2177.
# Erro ao abrir a imagem 2188.
# Erro ao abrir a imagem 2214.
# Erro ao abrir a imagem 2224.
# Erro ao abrir a imagem 223.
# Erro ao abrir a imagem 2234.
# Erro ao abrir a imagem 2240.
# Erro ao abrir a imagem 2248.
# Erro ao abrir a imagem 2252.
# Erro ao abrir a imagem 2253.
# Erro ao abrir a imagem 2254.
# Erro ao abrir a imagem 2255.
# Erro ao abrir a imagem 2256.
# Erro ao abrir a imagem 2275.
# Erro ao abrir a imagem 2282.
# Erro ao abrir a imagem 2292.
# Erro ao abrir a imagem 231.
# Erro ao abrir a imagem 2323.
# Erro ao abrir a imagem 2326.
# Erro ao abrir a imagem 2329.
# Erro ao abrir a imagem 2337.
# Erro ao abrir a imagem 2343.
# Erro ao abrir a imagem 2351.
# Erro ao abrir a imagem 2375.
# Erro ao abrir a imagem 2391.
# Erro ao abrir a imagem 2406.
# Erro ao abrir a imagem 2410.
# Erro ao abrir a imagem 242.
# Erro ao abrir a imagem 2428.
# Erro ao abrir a imagem 2446.
# Erro ao abrir a imagem 2463.
# Erro ao abrir a imagem 2501.
# Erro ao abrir a imagem 2502.
# Erro ao abrir a imagem 2519.
# Erro ao abrir a imagem 2532.
# Erro ao abrir a imagem 2539.
# Erro ao abrir a imagem 2558.
# Erro ao abrir a imagem 2589.
# Erro ao abrir a imagem 262.
# Erro ao abrir a imagem 2632.
# Erro ao abrir a imagem 2635.
# Erro ao abrir a imagem 2636.
# Erro ao abrir a imagem 2637.
# Erro ao abrir a imagem 2643.
# Erro ao abrir a imagem 2670.
# Erro ao abrir a imagem 2683.
# Erro ao abrir a imagem 2692.
# Erro ao abrir a imagem 2701.
# Erro ao abrir a imagem 2702.
# Erro ao abrir a imagem 2717.
# Erro ao abrir a imagem 2718.
# Erro ao abrir a imagem 275.
# Erro ao abrir a imagem 2757.
# Erro ao abrir a imagem 2759.
# Erro ao abrir a imagem 276.
# Erro ao abrir a imagem 2762.
# Erro ao abrir a imagem 2768.
# Erro ao abrir a imagem 2773.
# Erro ao abrir a imagem 2775.
# Erro ao abrir a imagem 2776.
# Erro ao abrir a imagem 2810.
# Erro ao abrir a imagem 2811.
# Erro ao abrir a imagem 2818.
# Erro ao abrir a imagem 2829.
# Erro ao abrir a imagem 2837.
# Erro ao abrir a imagem 284.
# Erro ao abrir a imagem 2847.
# Erro ao abrir a imagem 2871.
# Erro ao abrir a imagem 2892.
# Erro ao abrir a imagem 2899.
# Erro ao abrir a imagem 2952.
# Erro ao abrir a imagem 2957.
# Erro ao abrir a imagem 2964.
# Erro ao abrir a imagem 2977.
# Erro ao abrir a imagem 298.
# Erro ao abrir a imagem 299.
# Erro ao abrir a imagem 2995.
# Erro ao abrir a imagem 3004.
# Erro ao abrir a imagem 3008.
# Erro ao abrir a imagem 3027.
# Erro ao abrir a imagem 3034.
# Erro ao abrir a imagem 3036.
# Erro ao abrir a imagem 3039.
# Erro ao abrir a imagem 3050.
# Erro ao abrir a imagem 3051.
# Erro ao abrir a imagem 3057.
# Erro ao abrir a imagem 3064.
# Erro ao abrir a imagem 3065.
# Erro ao abrir a imagem 3122.
# Erro ao abrir a imagem 3124.
# Erro ao abrir a imagem 3125.
# Erro ao abrir a imagem 3129.
# Erro ao abrir a imagem 3131.
# Erro ao abrir a imagem 3132.
# Erro ao abrir a imagem 3135.
# Erro ao abrir a imagem 3136.
# Erro ao abrir a imagem 3137.
# Erro ao abrir a imagem 3138.
# Erro ao abrir a imagem 3139.
# Erro ao abrir a imagem 3140.
# Erro ao abrir a imagem 3141.
# Erro ao abrir a imagem 3142.
# Erro ao abrir a imagem 3143.
# Erro ao abrir a imagem 3144.
# Erro ao abrir a imagem 3145.
# Erro ao abrir a imagem 3146.
# Erro ao abrir a imagem 3147.
# Erro ao abrir a imagem 3148.
# Erro ao abrir a imagem 3150.
# Erro ao abrir a imagem 3151.
# Erro ao abrir a imagem 3152.
# Erro ao abrir a imagem 3153.
# Erro ao abrir a imagem 3155.
# Erro ao abrir a imagem 3156.
# Erro ao abrir a imagem 3157.
# Erro ao abrir a imagem 3158.
# Erro ao abrir a imagem 317.
# Erro ao abrir a imagem 325.
# Erro ao abrir a imagem 346.
# Erro ao abrir a imagem 352.
# Erro ao abrir a imagem 368.
# Erro ao abrir a imagem 376.
# Erro ao abrir a imagem 377.
# Erro ao abrir a imagem 400.
# Erro ao abrir a imagem 407.
# Erro ao abrir a imagem 408.
# Erro ao abrir a imagem 446.
# Erro ao abrir a imagem 447.
# Erro ao abrir a imagem 455.
# Erro ao abrir a imagem 465.
# Erro ao abrir a imagem 467.
# Erro ao abrir a imagem 474.
# Erro ao abrir a imagem 478.
# Erro ao abrir a imagem 493.
# Erro ao abrir a imagem 495.
# Erro ao abrir a imagem 504.
# Erro ao abrir a imagem 5238.
# Erro ao abrir a imagem 5239.
# Erro ao abrir a imagem 5240.
# Erro ao abrir a imagem 5241.
# Erro ao abrir a imagem 5242.
# Erro ao abrir a imagem 5244.
# Erro ao abrir a imagem 5245.
# Erro ao abrir a imagem 5246.
# Erro ao abrir a imagem 5247.
# Erro ao abrir a imagem 5248.
# Erro ao abrir a imagem 5249.
# Erro ao abrir a imagem 5251.
# Erro ao abrir a imagem 5252.
# Erro ao abrir a imagem 5253.
# Erro ao abrir a imagem 5254.
# Erro ao abrir a imagem 5255.
# Erro ao abrir a imagem 5256.
# Erro ao abrir a imagem 5258.
# Erro ao abrir a imagem 5259.
# Erro ao abrir a imagem 5261.
# Erro ao abrir a imagem 5265.
# Erro ao abrir a imagem 5266.
# Erro ao abrir a imagem 5267.
# Erro ao abrir a imagem 5269.
# Erro ao abrir a imagem 5270.
# Erro ao abrir a imagem 5271.
# Erro ao abrir a imagem 5272.
# Erro ao abrir a imagem 5273.
# Erro ao abrir a imagem 5275.
# Erro ao abrir a imagem 5276.
# Erro ao abrir a imagem 5278.
# Erro ao abrir a imagem 5279.
# Erro ao abrir a imagem 5280.
# Erro ao abrir a imagem 5281.
# Erro ao abrir a imagem 5283.
# Erro ao abrir a imagem 5284.
# Erro ao abrir a imagem 5285.
# Erro ao abrir a imagem 5287.
# Erro ao abrir a imagem 5289.
# Erro ao abrir a imagem 5290.
# Erro ao abrir a imagem 5291.
# Erro ao abrir a imagem 5292.
# Erro ao abrir a imagem 5293.
# Erro ao abrir a imagem 5294.
# Erro ao abrir a imagem 5296.
# Erro ao abrir a imagem 5297.
# Erro ao abrir a imagem 5298.
# Erro ao abrir a imagem 5299.
# Erro ao abrir a imagem 5300.
# Erro ao abrir a imagem 5302.
# Erro ao abrir a imagem 5303.
# Erro ao abrir a imagem 5304.
# Erro ao abrir a imagem 5306.
# Erro ao abrir a imagem 5307.
# Erro ao abrir a imagem 5308.
# Erro ao abrir a imagem 5310.
# Erro ao abrir a imagem 5311.
# Erro ao abrir a imagem 5312.
# Erro ao abrir a imagem 5313.
# Erro ao abrir a imagem 5314.
# Erro ao abrir a imagem 5316.
# Erro ao abrir a imagem 5317.
# Erro ao abrir a imagem 5318.
# Erro ao abrir a imagem 5320.
# Erro ao abrir a imagem 5322.
# Erro ao abrir a imagem 5323.
# Erro ao abrir a imagem 5325.
# Erro ao abrir a imagem 5326.
# Erro ao abrir a imagem 5327.
# Erro ao abrir a imagem 5328.
# Erro ao abrir a imagem 5329.
# Erro ao abrir a imagem 5330.
# Erro ao abrir a imagem 5331.
# Erro ao abrir a imagem 5332.
# Erro ao abrir a imagem 5333.
# Erro ao abrir a imagem 5334.
# Erro ao abrir a imagem 5335.
# Erro ao abrir a imagem 5336.
# Erro ao abrir a imagem 5339.
# Erro ao abrir a imagem 5340.
# Erro ao abrir a imagem 5341.
# Erro ao abrir a imagem 5342.
# Erro ao abrir a imagem 5343.
# Erro ao abrir a imagem 5344.
# Erro ao abrir a imagem 5345.
# Erro ao abrir a imagem 5346.
# Erro ao abrir a imagem 5347.
# Erro ao abrir a imagem 5348.
# Erro ao abrir a imagem 5350.
# Erro ao abrir a imagem 5352.
# Erro ao abrir a imagem 5355.
# Erro ao abrir a imagem 5357.
# Erro ao abrir a imagem 5359.
# Erro ao abrir a imagem 5360.
# Erro ao abrir a imagem 5361.
# Erro ao abrir a imagem 5362.
# Erro ao abrir a imagem 5363.
# Erro ao abrir a imagem 5364.
# Erro ao abrir a imagem 5365.
# Erro ao abrir a imagem 5366.
# Erro ao abrir a imagem 5367.
# Erro ao abrir a imagem 5371.
# Erro ao abrir a imagem 5372.
# Erro ao abrir a imagem 5373.
# Erro ao abrir a imagem 5374.
# Erro ao abrir a imagem 5375.
# Erro ao abrir a imagem 5376.
# Erro ao abrir a imagem 5377.
# Erro ao abrir a imagem 5378.
# Erro ao abrir a imagem 5380.
# Erro ao abrir a imagem 5382.
# Erro ao abrir a imagem 5383.
# Erro ao abrir a imagem 5384.
# Erro ao abrir a imagem 5385.
# Erro ao abrir a imagem 5386.
# Erro ao abrir a imagem 5388.
# Erro ao abrir a imagem 5389.
# Erro ao abrir a imagem 5390.
# Erro ao abrir a imagem 5391.
# Erro ao abrir a imagem 5392.
# Erro ao abrir a imagem 5394.
# Erro ao abrir a imagem 5395.
# Erro ao abrir a imagem 5396.
# Erro ao abrir a imagem 5397.
# Erro ao abrir a imagem 5398.
# Erro ao abrir a imagem 5399.
# Erro ao abrir a imagem 5400.
# Erro ao abrir a imagem 5403.
# Erro ao abrir a imagem 5404.
# Erro ao abrir a imagem 5405.
# Erro ao abrir a imagem 5406.
# Erro ao abrir a imagem 5407.
# Erro ao abrir a imagem 5408.
# Erro ao abrir a imagem 5409.
# Erro ao abrir a imagem 5410.
# Erro ao abrir a imagem 5411.
# Erro ao abrir a imagem 5412.
# Erro ao abrir a imagem 5413.
# Erro ao abrir a imagem 5415.
# Erro ao abrir a imagem 5416.
# Erro ao abrir a imagem 5417.
# Erro ao abrir a imagem 5418.
# Erro ao abrir a imagem 542.
# Erro ao abrir a imagem 5420.
# Erro ao abrir a imagem 5421.
# Erro ao abrir a imagem 5423.
# Erro ao abrir a imagem 5424.
# Erro ao abrir a imagem 5426.
# Erro ao abrir a imagem 5427.
# Erro ao abrir a imagem 5428.
# Erro ao abrir a imagem 5429.
# Erro ao abrir a imagem 543.
# Erro ao abrir a imagem 5431.
# Erro ao abrir a imagem 5432.
# Erro ao abrir a imagem 5433.
# Erro ao abrir a imagem 5434.
# Erro ao abrir a imagem 5436.
# Erro ao abrir a imagem 5437.
# Erro ao abrir a imagem 5438.
# Erro ao abrir a imagem 5439.
# Erro ao abrir a imagem 5440.
# Erro ao abrir a imagem 5441.
# Erro ao abrir a imagem 5443.
# Erro ao abrir a imagem 5444.
# Erro ao abrir a imagem 5445.
# Erro ao abrir a imagem 5446.
# Erro ao abrir a imagem 5447.
# Erro ao abrir a imagem 5448.
# Erro ao abrir a imagem 5449.
# Erro ao abrir a imagem 5452.
# Erro ao abrir a imagem 5453.
# Erro ao abrir a imagem 5456.
# Erro ao abrir a imagem 5458.
# Erro ao abrir a imagem 5460.
# Erro ao abrir a imagem 5461.
# Erro ao abrir a imagem 5462.
# Erro ao abrir a imagem 5463.
# Erro ao abrir a imagem 5464.
# Erro ao abrir a imagem 5465.
# Erro ao abrir a imagem 5466.
# Erro ao abrir a imagem 5468.
# Erro ao abrir a imagem 5469.
# Erro ao abrir a imagem 5470.
# Erro ao abrir a imagem 5472.
# Erro ao abrir a imagem 5474.
# Erro ao abrir a imagem 5477.
# Erro ao abrir a imagem 5478.
# Erro ao abrir a imagem 5479.
# Erro ao abrir a imagem 5481.
# Erro ao abrir a imagem 5483.
# Erro ao abrir a imagem 5484.
# Erro ao abrir a imagem 5485.
# Erro ao abrir a imagem 5487.
# Erro ao abrir a imagem 5488.
# Erro ao abrir a imagem 5489.
# Erro ao abrir a imagem 5490.
# Erro ao abrir a imagem 5491.
# Erro ao abrir a imagem 5493.
# Erro ao abrir a imagem 5495.
# Erro ao abrir a imagem 5497.
# Erro ao abrir a imagem 5499.
# Erro ao abrir a imagem 5500.
# Erro ao abrir a imagem 5502.
# Erro ao abrir a imagem 5503.
# Erro ao abrir a imagem 5504.
# Erro ao abrir a imagem 5507.
# Erro ao abrir a imagem 5508.
# Erro ao abrir a imagem 5509.
# Erro ao abrir a imagem 5510.
# Erro ao abrir a imagem 5511.
# Erro ao abrir a imagem 5512.
# Erro ao abrir a imagem 5517.
# Erro ao abrir a imagem 5518.
# Erro ao abrir a imagem 5520.
# Erro ao abrir a imagem 5524.
# Erro ao abrir a imagem 5526.
# Erro ao abrir a imagem 5527.
# Erro ao abrir a imagem 5528.
# Erro ao abrir a imagem 5529.
# Erro ao abrir a imagem 5530.
# Erro ao abrir a imagem 5531.
# Erro ao abrir a imagem 5533.
# Erro ao abrir a imagem 5535.
# Erro ao abrir a imagem 5536.
# Erro ao abrir a imagem 5537.
# Erro ao abrir a imagem 5539.
# Erro ao abrir a imagem 5541.
# Erro ao abrir a imagem 5542.
# Erro ao abrir a imagem 5543.
# Erro ao abrir a imagem 5544.
# Erro ao abrir a imagem 5545.
# Erro ao abrir a imagem 5547.
# Erro ao abrir a imagem 5548.
# Erro ao abrir a imagem 5550.
# Erro ao abrir a imagem 5551.
# Erro ao abrir a imagem 5552.
# Erro ao abrir a imagem 5554.
# Erro ao abrir a imagem 5555.
# Erro ao abrir a imagem 5556.
# Erro ao abrir a imagem 5557.
# Erro ao abrir a imagem 5558.
# Erro ao abrir a imagem 5560.
# Erro ao abrir a imagem 5561.
# Erro ao abrir a imagem 5562.
# Erro ao abrir a imagem 5563.
# Erro ao abrir a imagem 5564.
# Erro ao abrir a imagem 5567.
# Erro ao abrir a imagem 5568.
# Erro ao abrir a imagem 5569.
# Erro ao abrir a imagem 5572.
# Erro ao abrir a imagem 5574.
# Erro ao abrir a imagem 5575.
# Erro ao abrir a imagem 5576.
# Erro ao abrir a imagem 5577.
# Erro ao abrir a imagem 5578.
# Erro ao abrir a imagem 5579.
# Erro ao abrir a imagem 5580.
# Erro ao abrir a imagem 5581.
# Erro ao abrir a imagem 5583.
# Erro ao abrir a imagem 5586.
# Erro ao abrir a imagem 5588.
# Erro ao abrir a imagem 5589.
# Erro ao abrir a imagem 5590.
# Erro ao abrir a imagem 5591.
# Erro ao abrir a imagem 5592.
# Erro ao abrir a imagem 5593.
# Erro ao abrir a imagem 5594.
# Erro ao abrir a imagem 5595.
# Erro ao abrir a imagem 5597.
# Erro ao abrir a imagem 5598.
# Erro ao abrir a imagem 5600.
# Erro ao abrir a imagem 5601.
# Erro ao abrir a imagem 5602.
# Erro ao abrir a imagem 5603.
# Erro ao abrir a imagem 5607.
# Erro ao abrir a imagem 561.
# Erro ao abrir a imagem 5611.
# Erro ao abrir a imagem 5612.
# Erro ao abrir a imagem 5614.
# Erro ao abrir a imagem 5616.
# Erro ao abrir a imagem 5617.
# Erro ao abrir a imagem 5618.
# Erro ao abrir a imagem 5619.
# Erro ao abrir a imagem 5620.
# Erro ao abrir a imagem 5621.
# Erro ao abrir a imagem 5623.
# Erro ao abrir a imagem 5626.
# Erro ao abrir a imagem 5627.
# Erro ao abrir a imagem 5629.
# Erro ao abrir a imagem 5630.
# Erro ao abrir a imagem 5631.
# Erro ao abrir a imagem 5632.
# Erro ao abrir a imagem 5633.
# Erro ao abrir a imagem 5634.
# Erro ao abrir a imagem 5635.
# Erro ao abrir a imagem 5636.
# Erro ao abrir a imagem 5637.
# Erro ao abrir a imagem 5638.
# Erro ao abrir a imagem 5640.
# Erro ao abrir a imagem 5641.
# Erro ao abrir a imagem 5642.
# Erro ao abrir a imagem 5644.
# Erro ao abrir a imagem 5645.
# Erro ao abrir a imagem 5646.
# Erro ao abrir a imagem 5647.
# Erro ao abrir a imagem 5649.
# Erro ao abrir a imagem 5651.
# Erro ao abrir a imagem 5652.
# Erro ao abrir a imagem 5653.
# Erro ao abrir a imagem 5656.
# Erro ao abrir a imagem 5658.
# Erro ao abrir a imagem 5659.
# Erro ao abrir a imagem 5660.
# Erro ao abrir a imagem 5662.
# Erro ao abrir a imagem 5664.
# Erro ao abrir a imagem 5666.
# Erro ao abrir a imagem 5667.
# Erro ao abrir a imagem 5668.
# Erro ao abrir a imagem 5669.
# Erro ao abrir a imagem 5670.
# Erro ao abrir a imagem 5671.
# Erro ao abrir a imagem 5672.
# Erro ao abrir a imagem 5673.
# Erro ao abrir a imagem 5676.
# Erro ao abrir a imagem 5678.
# Erro ao abrir a imagem 5681.
# Erro ao abrir a imagem 5683.
# Erro ao abrir a imagem 5685.
# Erro ao abrir a imagem 5686.
# Erro ao abrir a imagem 5687.
# Erro ao abrir a imagem 5688.
# Erro ao abrir a imagem 5689.
# Erro ao abrir a imagem 5691.
# Erro ao abrir a imagem 5692.
# Erro ao abrir a imagem 5693.
# Erro ao abrir a imagem 5694.
# Erro ao abrir a imagem 5695.
# Erro ao abrir a imagem 5696.
# Erro ao abrir a imagem 5697.
# Erro ao abrir a imagem 5698.
# Erro ao abrir a imagem 5699.
# Erro ao abrir a imagem 5700.
# Erro ao abrir a imagem 5701.
# Erro ao abrir a imagem 5702.
# Erro ao abrir a imagem 5703.
# Erro ao abrir a imagem 5704.
# Erro ao abrir a imagem 5706.
# Erro ao abrir a imagem 5707.
# Erro ao abrir a imagem 5708.
# Erro ao abrir a imagem 5709.
# Erro ao abrir a imagem 5710.
# Erro ao abrir a imagem 5713.
# Erro ao abrir a imagem 5715.
# Erro ao abrir a imagem 5717.
# Erro ao abrir a imagem 5720.
# Erro ao abrir a imagem 5722.
# Erro ao abrir a imagem 5723.
# Erro ao abrir a imagem 5724.
# Erro ao abrir a imagem 5725.
# Erro ao abrir a imagem 5727.
# Erro ao abrir a imagem 5728.
# Erro ao abrir a imagem 5729.
# Erro ao abrir a imagem 5730.
# Erro ao abrir a imagem 5732.
# Erro ao abrir a imagem 5733.
# Erro ao abrir a imagem 5736.
# Erro ao abrir a imagem 5737.
# Erro ao abrir a imagem 5738.
# Erro ao abrir a imagem 5739.
# Erro ao abrir a imagem 5740.
# Erro ao abrir a imagem 5742.
# Erro ao abrir a imagem 5743.
# Erro ao abrir a imagem 5744.
# Erro ao abrir a imagem 5746.
# Erro ao abrir a imagem 5747.
# Erro ao abrir a imagem 5749.
# Erro ao abrir a imagem 5750.
# Erro ao abrir a imagem 5753.
# Erro ao abrir a imagem 5754.
# Erro ao abrir a imagem 5755.
# Erro ao abrir a imagem 576.
# Erro ao abrir a imagem 5762.
# Erro ao abrir a imagem 5766.
# Erro ao abrir a imagem 5767.
# Erro ao abrir a imagem 5768.
# Erro ao abrir a imagem 577.
# Erro ao abrir a imagem 5770.
# Erro ao abrir a imagem 5772.
# Erro ao abrir a imagem 5773.
# Erro ao abrir a imagem 5774.
# Erro ao abrir a imagem 5775.
# Erro ao abrir a imagem 5777.
# Erro ao abrir a imagem 5778.
# Erro ao abrir a imagem 5779.
# Erro ao abrir a imagem 5780.
# Erro ao abrir a imagem 5781.
# Erro ao abrir a imagem 5782.
# Erro ao abrir a imagem 5784.
# Erro ao abrir a imagem 5785.
# Erro ao abrir a imagem 5787.
# Erro ao abrir a imagem 5788.
# Erro ao abrir a imagem 5789.
# Erro ao abrir a imagem 5790.
# Erro ao abrir a imagem 5793.
# Erro ao abrir a imagem 5794.
# Erro ao abrir a imagem 5795.
# Erro ao abrir a imagem 5796.
# Erro ao abrir a imagem 5797.
# Erro ao abrir a imagem 5798.
# Erro ao abrir a imagem 5800.
# Erro ao abrir a imagem 5801.
# Erro ao abrir a imagem 5803.
# Erro ao abrir a imagem 5804.
# Erro ao abrir a imagem 5805.
# Erro ao abrir a imagem 5806.
# Erro ao abrir a imagem 5807.
# Erro ao abrir a imagem 5809.
# Erro ao abrir a imagem 5810.
# Erro ao abrir a imagem 5811.
# Erro ao abrir a imagem 5812.
# Erro ao abrir a imagem 5813.
# Erro ao abrir a imagem 5814.
# Erro ao abrir a imagem 5815.
# Erro ao abrir a imagem 5817.
# Erro ao abrir a imagem 5818.
# Erro ao abrir a imagem 5820.
# Erro ao abrir a imagem 5822.
# Erro ao abrir a imagem 5823.
# Erro ao abrir a imagem 5824.
# Erro ao abrir a imagem 5825.
# Erro ao abrir a imagem 5826.
# Erro ao abrir a imagem 5828.
# Erro ao abrir a imagem 5829.
# Erro ao abrir a imagem 5830.
# Erro ao abrir a imagem 5832.
# Erro ao abrir a imagem 5834.
# Erro ao abrir a imagem 5835.
# Erro ao abrir a imagem 5836.
# Erro ao abrir a imagem 5838.
# Erro ao abrir a imagem 5840.
# Erro ao abrir a imagem 5841.
# Erro ao abrir a imagem 5843.
# Erro ao abrir a imagem 5844.
# Erro ao abrir a imagem 5846.
# Erro ao abrir a imagem 5847.
# Erro ao abrir a imagem 5848.
# Erro ao abrir a imagem 5849.
# Erro ao abrir a imagem 5850.
# Erro ao abrir a imagem 5851.
# Erro ao abrir a imagem 5852.
# Erro ao abrir a imagem 5853.
# Erro ao abrir a imagem 5854.
# Erro ao abrir a imagem 5855.
# Erro ao abrir a imagem 5856.
# Erro ao abrir a imagem 5857.
# Erro ao abrir a imagem 5858.
# Erro ao abrir a imagem 5859.
# Erro ao abrir a imagem 5860.
# Erro ao abrir a imagem 5861.
# Erro ao abrir a imagem 5864.
# Erro ao abrir a imagem 5866.
# Erro ao abrir a imagem 5868.
# Erro ao abrir a imagem 5870.
# Erro ao abrir a imagem 5872.
# Erro ao abrir a imagem 5873.
# Erro ao abrir a imagem 5874.
# Erro ao abrir a imagem 5875.
# Erro ao abrir a imagem 5878.
# Erro ao abrir a imagem 5879.
# Erro ao abrir a imagem 5880.
# Erro ao abrir a imagem 5882.
# Erro ao abrir a imagem 5883.
# Erro ao abrir a imagem 5884.
# Erro ao abrir a imagem 5885.
# Erro ao abrir a imagem 5887.
# Erro ao abrir a imagem 5889.
# Erro ao abrir a imagem 5890.
# Erro ao abrir a imagem 5891.
# Erro ao abrir a imagem 5892.
# Erro ao abrir a imagem 5893.
# Erro ao abrir a imagem 5894.
# Erro ao abrir a imagem 5895.
# Erro ao abrir a imagem 5896.
# Erro ao abrir a imagem 5897.
# Erro ao abrir a imagem 5900.
# Erro ao abrir a imagem 5901.
# Erro ao abrir a imagem 5902.
# Erro ao abrir a imagem 5903.
# Erro ao abrir a imagem 5904.
# Erro ao abrir a imagem 5905.
# Erro ao abrir a imagem 5906.
# Erro ao abrir a imagem 5907.
# Erro ao abrir a imagem 5908.
# Erro ao abrir a imagem 5909.
# Erro ao abrir a imagem 5910.
# Erro ao abrir a imagem 5911.
# Erro ao abrir a imagem 5912.
# Erro ao abrir a imagem 5913.
# Erro ao abrir a imagem 5914.
# Erro ao abrir a imagem 5915.
# Erro ao abrir a imagem 5916.
# Erro ao abrir a imagem 5917.
# Erro ao abrir a imagem 5919.
# Erro ao abrir a imagem 5920.
# Erro ao abrir a imagem 5921.
# Erro ao abrir a imagem 5922.
# Erro ao abrir a imagem 5923.
# Erro ao abrir a imagem 5925.
# Erro ao abrir a imagem 5926.
# Erro ao abrir a imagem 5927.
# Erro ao abrir a imagem 5928.
# Erro ao abrir a imagem 5929.
# Erro ao abrir a imagem 5930.
# Erro ao abrir a imagem 5931.
# Erro ao abrir a imagem 5932.
# Erro ao abrir a imagem 5934.
# Erro ao abrir a imagem 5935.
# Erro ao abrir a imagem 5937.
# Erro ao abrir a imagem 5938.
# Erro ao abrir a imagem 5939.
# Erro ao abrir a imagem 5941.
# Erro ao abrir a imagem 5943.
# Erro ao abrir a imagem 5946.
# Erro ao abrir a imagem 5947.
# Erro ao abrir a imagem 5948.
# Erro ao abrir a imagem 5950.
# Erro ao abrir a imagem 5951.
# Erro ao abrir a imagem 5952.
# Erro ao abrir a imagem 5954.
# Erro ao abrir a imagem 5955.
# Erro ao abrir a imagem 5956.
# Erro ao abrir a imagem 5957.
# Erro ao abrir a imagem 5958.
# Erro ao abrir a imagem 5959.
# Erro ao abrir a imagem 596.
# Erro ao abrir a imagem 5960.
# Erro ao abrir a imagem 5961.
# Erro ao abrir a imagem 5964.
# Erro ao abrir a imagem 5966.
# Erro ao abrir a imagem 5967.
# Erro ao abrir a imagem 5968.
# Erro ao abrir a imagem 5970.
# Erro ao abrir a imagem 5972.
# Erro ao abrir a imagem 5973.
# Erro ao abrir a imagem 5974.
# Erro ao abrir a imagem 5980.
# Erro ao abrir a imagem 5982.
# Erro ao abrir a imagem 5984.
# Erro ao abrir a imagem 5985.
# Erro ao abrir a imagem 5986.
# Erro ao abrir a imagem 5987.
# Erro ao abrir a imagem 5988.
# Erro ao abrir a imagem 5989.
# Erro ao abrir a imagem 5990.
# Erro ao abrir a imagem 5991.
# Erro ao abrir a imagem 5992.
# Erro ao abrir a imagem 5993.
# Erro ao abrir a imagem 5994.
# Erro ao abrir a imagem 5996.
# Erro ao abrir a imagem 5998.
# Erro ao abrir a imagem 6001.
# Erro ao abrir a imagem 6002.
# Erro ao abrir a imagem 6003.
# Erro ao abrir a imagem 6004.
# Erro ao abrir a imagem 6005.
# Erro ao abrir a imagem 6006.
# Erro ao abrir a imagem 6007.
# Erro ao abrir a imagem 6008.
# Erro ao abrir a imagem 6009.
# Erro ao abrir a imagem 6011.
# Erro ao abrir a imagem 6012.
# Erro ao abrir a imagem 6013.
# Erro ao abrir a imagem 6016.
# Erro ao abrir a imagem 6018.
# Erro ao abrir a imagem 6019.
# Erro ao abrir a imagem 6020.
# Erro ao abrir a imagem 6022.
# Erro ao abrir a imagem 6023.
# Erro ao abrir a imagem 6025.
# Erro ao abrir a imagem 6026.
# Erro ao abrir a imagem 6027.
# Erro ao abrir a imagem 6028.
# Erro ao abrir a imagem 6031.
# Erro ao abrir a imagem 6032.
# Erro ao abrir a imagem 6033.
# Erro ao abrir a imagem 6034.
# Erro ao abrir a imagem 6035.
# Erro ao abrir a imagem 6036.
# Erro ao abrir a imagem 6037.
# Erro ao abrir a imagem 6038.
# Erro ao abrir a imagem 6039.
# Erro ao abrir a imagem 6040.
# Erro ao abrir a imagem 6044.
# Erro ao abrir a imagem 6045.
# Erro ao abrir a imagem 6047.
# Erro ao abrir a imagem 6048.
# Erro ao abrir a imagem 6049.
# Erro ao abrir a imagem 6051.
# Erro ao abrir a imagem 6052.
# Erro ao abrir a imagem 6053.
# Erro ao abrir a imagem 6054.
# Erro ao abrir a imagem 6055.
# Erro ao abrir a imagem 6056.
# Erro ao abrir a imagem 6057.
# Erro ao abrir a imagem 6058.
# Erro ao abrir a imagem 6059.
# Erro ao abrir a imagem 6060.
# Erro ao abrir a imagem 6061.
# Erro ao abrir a imagem 6062.
# Erro ao abrir a imagem 6063.
# Erro ao abrir a imagem 6064.
# Erro ao abrir a imagem 6065.
# Erro ao abrir a imagem 6066.
# Erro ao abrir a imagem 6068.
# Erro ao abrir a imagem 6069.
# Erro ao abrir a imagem 6070.
# Erro ao abrir a imagem 6071.
# Erro ao abrir a imagem 6072.
# Erro ao abrir a imagem 6074.
# Erro ao abrir a imagem 6075.
# Erro ao abrir a imagem 6076.
# Erro ao abrir a imagem 6078.
# Erro ao abrir a imagem 6079.
# Erro ao abrir a imagem 6080.
# Erro ao abrir a imagem 6081.
# Erro ao abrir a imagem 6082.
# Erro ao abrir a imagem 6083.
# Erro ao abrir a imagem 6084.
# Erro ao abrir a imagem 6085.
# Erro ao abrir a imagem 6086.
# Erro ao abrir a imagem 6087.
# Erro ao abrir a imagem 6088.
# Erro ao abrir a imagem 6089.
# Erro ao abrir a imagem 6090.
# Erro ao abrir a imagem 6091.
# Erro ao abrir a imagem 6092.
# Erro ao abrir a imagem 6093.
# Erro ao abrir a imagem 6094.
# Erro ao abrir a imagem 6097.
# Erro ao abrir a imagem 6098.
# Erro ao abrir a imagem 6099.
# Erro ao abrir a imagem 6100.
# Erro ao abrir a imagem 6101.
# Erro ao abrir a imagem 6102.
# Erro ao abrir a imagem 6103.
# Erro ao abrir a imagem 6104.
# Erro ao abrir a imagem 6105.
# Erro ao abrir a imagem 6106.
# Erro ao abrir a imagem 6107.
# Erro ao abrir a imagem 6108.
# Erro ao abrir a imagem 6109.
# Erro ao abrir a imagem 6110.
# Erro ao abrir a imagem 6111.
# Erro ao abrir a imagem 6112.
# Erro ao abrir a imagem 6113.
# Erro ao abrir a imagem 6115.
# Erro ao abrir a imagem 6118.
# Erro ao abrir a imagem 6119.
# Erro ao abrir a imagem 6121.
# Erro ao abrir a imagem 6122.
# Erro ao abrir a imagem 6123.
# Erro ao abrir a imagem 6125.
# Erro ao abrir a imagem 6126.
# Erro ao abrir a imagem 6127.
# Erro ao abrir a imagem 6128.
# Erro ao abrir a imagem 6129.
# Erro ao abrir a imagem 6131.
# Erro ao abrir a imagem 6132.
# Erro ao abrir a imagem 6134.
# Erro ao abrir a imagem 6136.
# Erro ao abrir a imagem 6140.
# Erro ao abrir a imagem 6141.
# Erro ao abrir a imagem 6142.
# Erro ao abrir a imagem 6143.
# Erro ao abrir a imagem 6144.
# Erro ao abrir a imagem 6145.
# Erro ao abrir a imagem 6146.
# Erro ao abrir a imagem 6148.
# Erro ao abrir a imagem 6149.
# Erro ao abrir a imagem 6150.
# Erro ao abrir a imagem 6151.
# Erro ao abrir a imagem 6152.
# Erro ao abrir a imagem 6153.
# Erro ao abrir a imagem 6155.
# Erro ao abrir a imagem 6157.
# Erro ao abrir a imagem 6159.
# Erro ao abrir a imagem 6161.
# Erro ao abrir a imagem 625.
# Erro ao abrir a imagem 634.
# Erro ao abrir a imagem 648.
# Erro ao abrir a imagem 659.
# Erro ao abrir a imagem 66.
# Erro ao abrir a imagem 67.
# Erro ao abrir a imagem 687.
# Erro ao abrir a imagem 689.
# Erro ao abrir a imagem 701.
# Erro ao abrir a imagem 703.
# Erro ao abrir a imagem 716.
# Erro ao abrir a imagem 718.
# Erro ao abrir a imagem 720.
# Erro ao abrir a imagem 725.
# Erro ao abrir a imagem 730.
# Erro ao abrir a imagem 732.
# Erro ao abrir a imagem 739.
# Erro ao abrir a imagem 747.
# Erro ao abrir a imagem 791.
# Erro ao abrir a imagem 80.
# Erro ao abrir a imagem 801.
# Erro ao abrir a imagem 804.
# Erro ao abrir a imagem 844.
# Erro ao abrir a imagem 851.
# Erro ao abrir a imagem 858.
# Erro ao abrir a imagem 86.
# Erro ao abrir a imagem 869.
# Erro ao abrir a imagem 894.
# Erro ao abrir a imagem 898.
# Erro ao abrir a imagem 903.
# Erro ao abrir a imagem 909.
# Erro ao abrir a imagem 920.
# Erro ao abrir a imagem 922.
# Erro ao abrir a imagem 924.
# Erro ao abrir a imagem 926.
# Erro ao abrir a imagem 927.
# Erro ao abrir a imagem 930.
# Erro ao abrir a imagem 942.
# Erro ao abrir a imagem 943.
# Erro ao abrir a imagem 953.
# Erro ao abrir a imagem 96.
# Erro ao abrir a imagem 960.
# Erro ao abrir a imagem 967.
# Erro ao abrir a imagem 969.
# Erro ao abrir a imagem 975.
# Erro ao abrir a imagem 976.
# Erro ao abrir a imagem 982.
# Erro ao abrir a imagem 995.
# Erro ao abrir a imagem 40.
# Erro ao abrir a imagem 45.
# Erro ao abrir a imagem 47.
# O SHAPE DO X É ()
# E O SHAPE DO Y É (0,)!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-dbe7a06025e7> in <module>
#     226
#     227 # define model
# --> 228 model, eval_model, manipulate_model = CapsNet(input_shape=x_train.shape[1:],#np.shape(x_train),
#     229                                                   n_class=5,
#     230                                                   routings=3, #args.routings,
#
# <ipython-input-20-dbe7a06025e7> in CapsNet(input_shape, n_class, routings, batch_size)
#      48
#      49     # Layer 1: Just a conventional Conv2D layer
# ---> 50     conv1 = layers.Conv2D(filters=256, kernel_size=9, strides=1, padding='valid', activation='relu', name='conv1')(x)
#      51
#      52     # Layer 2: Conv2D layer with `squash` activation, then reshape to [None, num_capsule, dim_capsule]
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     883         # TODO(reedwm): We should assert input compatibility after the inputs
#     884         # are casted, not before.
# --> 885         input_spec.assert_input_compatibility(self.input_spec, inputs,
#     886                                               self.name)
#     887         if (any(isinstance(x, ragged_tensor.RaggedTensor) for x in input_list)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     174       ndim = x.shape.ndims
#     175       if ndim != spec.ndim:
# --> 176         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#     177                          layer_name + ' is incompatible with the layer: '
#     178                          'expected ndim=' + str(spec.ndim) + ', found ndim=' +
#
# ValueError: Input 0 of layer conv1 is incompatible with the layer: expected ndim=4, found ndim=1. Full shape received: [100]
