# %%
import PIL 
import csv
import glob, os
from numpy import *
from PIL import Image
from matplotlib import pyplot
from resizeimage import resizeimage
from keras.preprocessing.image import *
import pandas as pd

PATH          = '/Users/Pandessa/Documents/MEGA/UFRRJ/TCC/Projeto/rotulacao-bd.csv'
PATH_BKP      = '/Users/Pandessa/Documents/MEGA/UFRRJ/TCC/Projeto/ImagensTreino'
BASE_UFJF     = '/Users/Pandessa/Documents/MEGA/UFRRJ/TCC/Projeto/ImagensUFJF/*.jpg'
CONJ_TREINO   = '/Users/Pandessa/Documents/MEGA/UFRRJ/TCC/Projeto/ImagensTreino/*.jpg'

LARGURA       = 80
ALTURA        = 80

'''
#print(nome(i))
#pyplot.imshow(pixels) - serve para printar a imagem em forma de gráfico
'''
'''
def nome(diretorio):

    nome = diretorio.split("\\") # pega apenas o 'id.jpg'
    nome = nome[1]
    nome = nome.split(".jpg")  # segundo split para pegar apenas o id
    return nome[0]
'''

def criarDiretorio(id_img, imagem):
    foto = PATH_BKP+"\\"+str(id_img)+".jpg"
    
    if not os.path.exists(PATH_BKP):
        os.makedirs(PATH_BKP)
        try:
            imagem.save(foto)
        except:
            print("Erro ao salvar a imagem "+str(id_img)+".")
    else:
        if not os.path.exists(foto):
            try:
                imagem.save(foto)
            except:
                print("Erro ao salvar a imagem "+str(id_img)+".")
            
def busca_csv(id_img, objImg):
    
    df_data = pd.read_csv(PATH)
    df_data.set_index('id_imagem', inplace=True) # tornando a coluna id_imagem em indice
    
    try:
        caracteristicas = df_data.loc[id_img].values
        return caracteristicas
    except:
        print("Imagem"+str(id_img)+" não encontrada.\n")
    
    return False
            
def salva_imagem():
    
    id_img = 0
    df_data = pd.read_csv(PATH)
    df_data.set_index('id_imagem', inplace=True) # tornando a coluna id_imagem em indice
    
    for i in glob.glob(BASE_UFJF):
        
        try:
            img    = Image.open(i)
        except:
            print("Imagem "+nome(i)+" não pode ser aberta.")
            
        id_img = int(nome(i)) # transforma id da imagem em inteiro antes de passar pra busca
        
        try:
            df_data.loc[id_img].values # se a imagem tá na planilha de rotulação, ela é salva na pasta
            img = img.resize((LARGURA, ALTURA), PIL.Image.ANTIALIAS)
            criarDiretorio(id_img, img) # armazena a imagem encontrada no csv
        except:
            continue
        
def load_data(DIRETORIO):
    
    x = [] # lista das imagens
    y = [] # lista de atributos das imagens (corCabelo, corOlhos...)
    
    for i in glob.glob(DIRETORIO):
        
        img             = Image.open(i)
        pixels          = asarray(img).astype('float32') #transforma a imagem em um array de pixels
        pixels          = pixels/pixels.max()
        caracteristicas = busca_csv(i, img)
        x.append(pixels)
        y.append(caracteristicas)
        
    return x,y

salva_imagem()
#x,y = load_data(CONJ_TREINO)

print(x)
# Out:
# Erro ao salvar a imagem 3122.
# Erro ao salvar a imagem 3143.
# Erro ao salvar a imagem 3145.
# Erro ao salvar a imagem 3146.
# Erro ao salvar a imagem 3158.
# Imagem 4430 não pode ser aberta.
# Imagem 4721 não pode ser aberta.
# Imagem 5978 não pode ser aberta.
# Imagem 7634 não pode ser aberta.
# Imagem 7635 não pode ser aberta.
# Imagem 7636 não pode ser aberta.
# Imagem 7637 não pode ser aberta.
# Imagem 7638 não pode ser aberta.
# Imagem 7639 não pode ser aberta.
# Imagem 7640 não pode ser aberta.
# Imagem 7641 não pode ser aberta.
# Imagem 7642 não pode ser aberta.
# Imagem 7643 não pode ser aberta.
# Imagem 7644 não pode ser aberta.
# Imagem 7645 não pode ser aberta.
# Imagem 7646 não pode ser aberta.
# Imagem 7647 não pode ser aberta.
# Imagem 7648 não pode ser aberta.
# Imagem 7649 não pode ser aberta.
# Imagem 7650 não pode ser aberta.
# Imagem 7651 não pode ser aberta.
# Imagem 7652 não pode ser aberta.
# Imagem 7653 não pode ser aberta.
# Imagem 7654 não pode ser aberta.
# Imagem 7655 não pode ser aberta.
# Imagem 7656 não pode ser aberta.
# Imagem 7657 não pode ser aberta.
# Imagem 7658 não pode ser aberta.
# Imagem 7659 não pode ser aberta.
# Imagem 7660 não pode ser aberta.
# Imagem 7661 não pode ser aberta.
# Imagem 7662 não pode ser aberta.
# Imagem 7663 não pode ser aberta.
# Imagem 7664 não pode ser aberta.
# Imagem 7665 não pode ser aberta.
# Imagem 7666 não pode ser aberta.
# Imagem 7667 não pode ser aberta.
# Imagem 7668 não pode ser aberta.
# Imagem 7670 não pode ser aberta.
# Imagem 7671 não pode ser aberta.
# Imagem 7672 não pode ser aberta.
# Imagem 7673 não pode ser aberta.
# Imagem 7674 não pode ser aberta.
# Imagem 7675 não pode ser aberta.
# Imagem 7676 não pode ser aberta.
# Imagem 7677 não pode ser aberta.
# Imagem 7678 não pode ser aberta.
# Imagem 7679 não pode ser aberta.
# Imagem 7680 não pode ser aberta.
# Imagem 7681 não pode ser aberta.
# Imagem 7682 não pode ser aberta.
# Imagem 7683 não pode ser aberta.
# Imagem 7684 não pode ser aberta.
# Imagem 7685 não pode ser aberta.
# Imagem 7686 não pode ser aberta.
# Imagem 7687 não pode ser aberta.
# Imagem 7688 não pode ser aberta.
# Imagem 7689 não pode ser aberta.
# Imagem 7690 não pode ser aberta.
# Imagem 7691 não pode ser aberta.
# Imagem 7692 não pode ser aberta.
# Imagem 7693 não pode ser aberta.
# Imagem 7694 não pode ser aberta.
# Imagem 7695 não pode ser aberta.
# Imagem 7696 não pode ser aberta.
# Imagem 7697 não pode ser aberta.
# Imagem 7698 não pode ser aberta.
# Imagem 7699 não pode ser aberta.
# Imagem 7700 não pode ser aberta.
# Imagem 7701 não pode ser aberta.
# Imagem 7702 não pode ser aberta.
# Imagem 7703 não pode ser aberta.
# Imagem 7704 não pode ser aberta.
# Imagem 7705 não pode ser aberta.
# Imagem 7706 não pode ser aberta.
# Imagem 7707 não pode ser aberta.
# Imagem 7708 não pode ser aberta.
# Imagem 7709 não pode ser aberta.
# Imagem 7710 não pode ser aberta.
# Imagem 7711 não pode ser aberta.
# Imagem 7712 não pode ser aberta.
# Imagem 7713 não pode ser aberta.
# Imagem 7714 não pode ser aberta.
# Imagem 7715 não pode ser aberta.
# Imagem 7716 não pode ser aberta.
# Imagem 7717 não pode ser aberta.
# Imagem 7718 não pode ser aberta.
# Imagem 7719 não pode ser aberta.
# Imagem 7720 não pode ser aberta.
# Imagem 7721 não pode ser aberta.
# Imagem 7722 não pode ser aberta.
# Imagem 7723 não pode ser aberta.
# Imagem 7724 não pode ser aberta.
# Imagem 7725 não pode ser aberta.
# Imagem 7726 não pode ser aberta.
# Imagem 7727 não pode ser aberta.
# Imagem 7728 não pode ser aberta.
# Imagem 7729 não pode ser aberta.
# Imagem 7730 não pode ser aberta.
# Imagem 7731 não pode ser aberta.
# Imagem 7732 não pode ser aberta.
# Imagem 7733 não pode ser aberta.
# Imagem 7734 não pode ser aberta.
# Imagem 7735 não pode ser aberta.
# Imagem 7736 não pode ser aberta.
# Imagem 7737 não pode ser aberta.
# Imagem 7738 não pode ser aberta.
# Imagem 7739 não pode ser aberta.
# Imagem 7740 não pode ser aberta.
# Imagem 7741 não pode ser aberta.
# Imagem 7742 não pode ser aberta.
# Imagem 7743 não pode ser aberta.
# Imagem 7744 não pode ser aberta.
# Imagem 7745 não pode ser aberta.
# Imagem 7746 não pode ser aberta.
# Imagem 7747 não pode ser aberta.
# Imagem 7748 não pode ser aberta.
# Imagem 7749 não pode ser aberta.
# Imagem 7750 não pode ser aberta.
# Imagem 7751 não pode ser aberta.
# Imagem 7752 não pode ser aberta.
# Imagem 7753 não pode ser aberta.
# Imagem 7754 não pode ser aberta.
# Imagem 7755 não pode ser aberta.
# Imagem 7756 não pode ser aberta.
# Imagem 7757 não pode ser aberta.
# Imagem 7758 não pode ser aberta.
# Imagem 7759 não pode ser aberta.
# Imagem 7760 não pode ser aberta.
# Imagem 7761 não pode ser aberta.
# Imagem 7762 não pode ser aberta.
# Imagem 7763 não pode ser aberta.
# Imagem 7764 não pode ser aberta.
# Imagem 7765 não pode ser aberta.
# Imagem 7766 não pode ser aberta.
# Imagem 7767 não pode ser aberta.
# Imagem 7768 não pode ser aberta.
# Imagem 7769 não pode ser aberta.
# Imagem 7770 não pode ser aberta.
# Imagem 7771 não pode ser aberta.
# Imagem 7772 não pode ser aberta.
# Imagem 7773 não pode ser aberta.
# Imagem 7775 não pode ser aberta.
# Imagem 7776 não pode ser aberta.
# Imagem 7777 não pode ser aberta.
# Imagem 7778 não pode ser aberta.
# Imagem 7779 não pode ser aberta.
# Imagem 7780 não pode ser aberta.
# Imagem 7781 não pode ser aberta.
# Imagem 7782 não pode ser aberta.
# Imagem 7783 não pode ser aberta.
# Imagem 7784 não pode ser aberta.
# Imagem 8506 não pode ser aberta.
# Imagem 8509 não pode ser aberta.
# Imagem 8523 não pode ser aberta.
# Imagem 8602 não pode ser aberta.
# Imagem 8603 não pode ser aberta.
# Imagem 8604 não pode ser aberta.
# Imagem 8605 não pode ser aberta.
# Imagem 8606 não pode ser aberta.
# Imagem 8607 não pode ser aberta.
# Imagem 8608 não pode ser aberta.
# Imagem 8609 não pode ser aberta.
# Imagem 8610 não pode ser aberta.
# Imagem 8611 não pode ser aberta.
# Imagem 8613 não pode ser aberta.
# Imagem 8614 não pode ser aberta.
# Imagem 8615 não pode ser aberta.
# Imagem 8616 não pode ser aberta.

# %%
from keras.datasets import mnist
from matplotlib import pyplot

(x_treino, x_teste), (y_treino, y_teste) = mnist.load_data()

#pyplot.imshow(x_treino[0])
#print(len(x_treino[0]))
